# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    "../data/restricted/kidney_waitlist_analytic.csv.gz",
    dtype={
        "PREV_TX": "string",
        "TX_DATE": "string",
        "DON_TY": "string",
        "MULTIORG": "string",
        "ORGAN": "string",
        "TRR_ID_CODE": "string",
    },
    low_memory=False,
)

# %%
num_df = df.select_dtypes(include=["int64", "float64"])
num_df
# Out:
#         A2A2B_ELIGIBILITY  BMI_TCR  FUNC_STAT_TCR  INIT_STAT  INIT_CPRA  \
# 0                     NaN    31.63         2080.0       4099        0.0
# 1                     NaN    30.04         2070.0       4099        0.0
# 2                     NaN    32.85         2070.0       4099        0.0
# 3                     NaN    20.00         2090.0       4099        0.0
# 4                     NaN    23.30         2070.0       4010        0.0
# ...                   ...      ...            ...        ...        ...
# 494857                NaN    24.14         2030.0       4010        0.0
# 494858                NaN    20.02         2040.0       4010        0.0
# 494859                NaN    23.87         2040.0       4010        0.0
# 494860                NaN    28.31          998.0       4010        0.0
# 494861                NaN    33.68         2070.0       4010        NaN
#
#         END_CPRA  REM_CD  DAYSWAIT_CHRON  END_STAT  INIT_AGE  ...  WL_ID_CODE  \
# 0           0.00     8.0           287.0      4099        53  ...     1526706
# 1            NaN    24.0          2322.0      4099        56  ...     1519605
# 2           0.00     8.0           604.0      4099        47  ...     1535094
# 3           0.00    13.0           909.0      4099        61  ...     1527782
# 4           0.00    13.0           231.0      4099        61  ...     1517273
# ...          ...     ...             ...       ...       ...  ...         ...
# 494857      0.00     4.0             1.0      4010        57  ...     1493235
# 494858      0.00     4.0             0.0      4010        30  ...     1512498
# 494859      0.00     4.0             0.0      4010        31  ...     1537643
# 494860      0.83     4.0           188.0      4010        45  ...     1697126
# 494861       NaN     4.0           121.0      4010        55  ...     1801603
#
#         DIAG_KI  PSTATUS   PTIME  DONOR_ID  LISTING_CTR_CODE  event_adverse  \
# 0           NaN      NaN     NaN       NaN             13609              1
# 1           NaN      NaN     NaN       NaN              6975              0
# 2           NaN      NaN     NaN       NaN             19716              1
# 3           NaN      NaN     NaN       NaN              8587              1
# 4           NaN      NaN     NaN       NaN             18352              1
# ...         ...      ...     ...       ...               ...            ...
# 494857   3027.0      1.0   297.0  569362.0             25110              0
# 494858   3069.0      1.0  1644.0  575999.0             25110              0
# 494859   3040.0      1.0   352.0  585230.0              5704              0
# 494860   3070.0      0.0  1081.0  662023.0             11532              0
# 494861    999.0      0.0   389.0  701597.0               124              0
#
#         event_transplant  censored  days_to_event
# 0                      0         0          287.0
# 1                      0         0         2322.0
# 2                      0         0          604.0
# 3                      0         0          909.0
# 4                      0         0          231.0
# ...                  ...       ...            ...
# 494857                 1         0            1.0
# 494858                 1         0            0.0
# 494859                 1         0            0.0
# 494860                 1         0          188.0
# 494861                 1         0          121.0
#
# [494862 rows x 24 columns]

# %%
corr_matrix = num_df.corr()[["event_adverse"]]

corr_matrix = corr_matrix.loc[
    corr_matrix["event_adverse"].abs().sort_values(ascending=False).index
]

sns.heatmap(corr_matrix, annot=True)

plt.title("Correlation with event_adverse")
plt.show()
